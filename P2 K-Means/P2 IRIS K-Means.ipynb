# %% [markdown]
# ## Project II: Iris clustering using K-Means - TSF GRIP
# ### Author: J.Zakaria
# In this project we'll use k-means from sickit-learn to predict the optimum number of clusters for iris data.
# ### Assessing the data:

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from matplotlib import style
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the iris dataset
iris = pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
sns.set_theme()

# %%
plt.figure(figsize=(10, 6)) #dpi=80

plt.scatter(x="SepalLengthCm", y="SepalWidthCm", data = iris, s = 70)

plt.xlabel("Sepal lenght", fontsize=13.5)
plt.ylabel("Sepal width", fontsize=13.5)
plt.title("Sepal lenght vs Sepal width", fontsize=17, fontweight="bold")

plt.show()

# %%
plt.figure(figsize=(10, 6)) #dpi=80

plt.scatter(x="PetalLengthCm", y="PetalWidthCm", data = iris, s = 70)

plt.xlabel("Petal lenght", fontsize=13.5)
plt.ylabel("Petal width", fontsize=13.5)
plt.title("Petal lenght vs Petal width", fontsize=17, fontweight="bold")

plt.show()

# %% [markdown]
# ### Preparing the data and runing the model
# First we get only the values of our 4 features, wthout column names.

# %%
features = iris.iloc[:,[1,2,3,4]].values

# %% [markdown]
# ##### Let's find the optimum number of clusters k

# %%
# Finding the optimum number of clusters for k-means classification
#x = iris_df.values

x = features

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f68092d0790>
# Traceback (most recent call last):
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.figure(figsize=(10, 6)) #dpi=80

plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# As we can see the optimum number of clusters is 3, let's fit the model.

# %%
kmeans = KMeans(n_clusters = 3, init = 'random',
                max_iter = 300, n_init = 10, tol=1e-04, random_state = 0)
y_kmeans = kmeans.fit_predict(x)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f680c6dd670>
# Traceback (most recent call last):
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/user/miniconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
plt.figure(figsize=(10, 6)) #dpi=80

plt.scatter(x[y_kmeans==0,0], x[y_kmeans==0,1], s = 80, color='skyblue', label='Iris-setosa')
plt.scatter(x[y_kmeans==1,0], x[y_kmeans==1,1], s = 80, label='Iris-versicolor')
plt.scatter(x[y_kmeans==2,0], x[y_kmeans==2,1], s = 80, color='lime', label='Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 300, c = 'red', label = 'Centroids', marker='*')

plt.xlabel("Sepal lenght", fontsize=13.5)
plt.ylabel("Sepal width", fontsize=13.5)
plt.title("Iris Clusters", fontsize=17, fontweight="bold")

plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate the model
# First let's see **Iris-setosa**

# %%
iris[iris["Species"] == "Iris-setosa"].describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %% [markdown]
# Like the plot the Sepal lenght is between 4.3 and 5.8, the Sepal width is between 2.3 and 4.4. Let's check **Iris-versicolor**

# %%
iris[iris["Species"] == "Iris-versicolor"].describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %% [markdown]
# Like the plot the Sepal lenght is between 4.9 and 7, the Sepal width is between 2 and 3.4. Let's check **Iris-virginica**

# %%
iris[iris["Species"] == "Iris-virginica"].describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %% [markdown]
# Like the plot the Sepal lenght is between 4.9 and 7.9, the Sepal width is between 2.2 and 3.8
